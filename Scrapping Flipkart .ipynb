# %% [markdown]
# # Importing Packages

# %%
import requests 
from bs4 import BeautifulSoup 
import pandas

# %%
base = 'https://www.flipkart.com'

for i in range(2,10):
    base_url = "https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)

# %%
req = requests.get(base_url)

# %%
print(req)
# Out:
# <Response [200]>

# %%
content = BeautifulSoup(req.content,'html.parser')

# %%
print(len(content))
# Out:
# 2

# %%
print(content)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup = BeautifulSoup(req.text, 'lxml')
print(len(soup))
print(soup)
# Out:
# 2
# <!DOCTYPE html>
# ...

# %%
next_page = soup.find('a', class_ = '_1LKTO3')['href']

# %%
complete_next_page = base+next_page

# %%
complete_next_page
# Out:
# 'https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2'

# %%
base_url = complete_next_page

# %%
r = requests.get(base_url)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.text,"lxml")

# %%
while True:
    next_page = soup.find('a', class_ = '_1LKTO3')['href']
    complete_next_page = base+next_page
    base_url = complete_next_page 
    soup = BeautifulSoup(r.text,"lxml")

# %%
data = content.find_all('div',{'class','_4rR01T'})

# %%
print(data)
# Out:
# [<div class="_4rR01T">REDMI 10 Power (Sporty Orange, 128 GB)</div>, <div class="_4rR01T">Redmi 9A Sport (Carbon Black, 32 GB)</div>, <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>, <div class="_4rR01T">Redmi 9A Sport (Metallic Blue, 32 GB)</div>, <div class="_4rR01T">Xiaomi 11Lite NE (Vinyl Black, 128 GB)</div>, <div class="_4rR01T">Redmi 10 Prime (Phantom Black, 64 GB)</div>, <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>, <div class="_4rR01T">Redmi 9A (Nature Green, 32 GB)</div>, <div class="_4rR01T">Mi 11 Lite (Vinyl Black, 128 GB)</div>, <div class="_4rR01T">Mi 11 Lite (Jazz Blue, 128 GB)</div>, <div class="_4rR01T">Redmi 9 (Carbon Black, 64 GB)</div>, <div class="_4rR01T">Redmi 6 (Black, 32 GB)</div>, <div class="_4rR01T">Xiaomi 12 Pro 5G (Noir Black, 256 GB)</div>, <div class="_4rR01T">REDMI 10 Power (Power Black, 128 GB)</div>, <div class="_4rR01T">Redmi 7A (Matte Blue, 32 GB)</div>, <div class="_4rR01T">Redmi 6 (Gold, 32 GB)</div>, <div class="
# ...

# %%
phone_names = []
phone_links = []
phone_ratings = []
start_link = 'https://www.flipkart.com'

# %%
for items in data:
    rest_link = items.find('a')['href']
    name = items.find('div', attrs = {'class':'_4rR01T'})
    phone_names.append(name.text)
    phone_links.append(start_link+rest_link)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16428\2814695829.py in <module>
#       1 for items in data:
# ----> 2     rest_link = items.find('a')['href']
#       3     name = items.find('div', attrs = {'class':'_4rR01T'})
#       4     phone_names.append(name.text)
#       5     phone_links.append(start_link+rest_link)
#
# TypeError: 'NoneType' object is not subscriptable
